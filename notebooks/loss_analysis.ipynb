# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
dir = '../DNNs/20180312_162500/k_4/'
fname = 'loss_results.npz'
dat = np.load(os.path.join(dir, fname))

loss_train_batch_history = dat['loss_train_batch_history']
lr_batch_history = dat['lr_batch_history']
loss_train_epoch_history = dat['loss_train_epoch_history']
loss_valid_epoch_history = dat['loss_valid_epoch_history']
time_epoch_history = dat['time_epoch_history']
epoch_list = dat['epoch_list']
best_epoch = dat['best_epoch']

# %%
plt.semilogy(loss_train_batch_history)
plt.xlabel('iteration')
# Out:
# Text(0.5,0,'iteration')

# %%
plt.semilogy(epoch_list, loss_train_epoch_history)
plt.semilogy(epoch_list, loss_valid_epoch_history)
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')
